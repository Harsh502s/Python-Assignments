# %%
# Creating a web crawler to scrape data from the 99acres.com website

# Importing the required libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
url = r'https://www.nobroker.in/property/sale/pune/multiple?searchParam=...&radius=2.0&propertyAge=0&city=pune&locality=Hadapsar,Kharadi,Wagholi#signup-login'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the tags that contain the data you want to extract
results = soup.find_all('div', class_='nb__7nqQI')
for result in results:
    print(result.text, end='\n'*2)
# Out:
# Not under loan₹ ₹60 Lacs₹6,129 per sq.ft.₹34,388/MonthEstimated EMI979 sqftBuiltup1/15EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹32 Lacs₹5,818 per sq.ft.₹18,340/MonthEstimated EMI550 sqftBuiltup1/27EastFacing1 BHKApartment Type1BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹65 Lacs₹9,091 per sq.ft.₹37,254/MonthEstimated EMI715 sqftBuiltup1/7SouthFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹30 Lacs₹4,983 per sq.ft.₹17,194/MonthEstimated EMI602 sqftBuiltup1/21Commute FriendlySouthFacing1 BHKApartment Type1BathroomsBikeParkingGet Owner Details
#
# Not under loan₹ ₹1.2 Crores₹10,000 per sq.ft.₹68,777/MonthEstimated EMI1,200 sqftBuiltup1/10EastFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹73 Lacs₹7,487 per sq.ft.₹41,839/MonthEstimated EMI975 sqftBuiltup1/61NorthFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹51 Lacs₹5,095 per sq.ft.₹29,230/MonthEstimated EMI1,001 sqftBuiltup1/30WestFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹56 Lacs₹5,895 per sq.ft.₹32,096/MonthEstimated EMI950 sqftBuiltup1/4EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹92 Lacs₹8,949 per sq.ft.₹52,729/MonthEstimated EMI1,028 sqftBuiltup1/27EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹80 Lacs₹6,400 per sq.ft.₹45,851/MonthEstimated EMI1,250 sqftBuiltup1/16WestFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹1.07 Crores₹7,477 per sq.ft.₹61,326/MonthEstimated EMI1,431 sqftBuiltup1/46EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹1.28 Crores₹13,142 per sq.ft.₹73,362/MonthEstimated EMI974 sqftBuiltup1/39South-EastFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹84 Lacs₹5,970 per sq.ft.₹48,144/MonthEstimated EMI1,407 sqftBuiltup1/26WestFacing3 BHKApartment Type3BathroomsCarParkingGet Owner Details
#
# Not under loan₹ ₹26.5 Lacs₹5,279 per sq.ft.₹15,188/MonthEstimated EMI502 sqftBuiltup1/8EastFacing1 BHKApartment Type1BathroomsBikeParkingGet Owner Details
#
# Under Loan₹ ₹75 Lacs₹5,906 per sq.ft.₹42,985/MonthEstimated EMI1,270 sqftBuiltup1/25EastFacing3 BHKApartment Type3BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹60 Lacs₹6,944 per sq.ft.₹34,388/MonthEstimated EMI864 sqftBuiltup1/33EastFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹64 Lacs₹5,926 per sq.ft.₹36,681/MonthEstimated EMI1,080 sqftBuiltup1/33EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹1.2 Crores₹7,417 per sq.ft.₹68,777/MonthEstimated EMI1,618 sqftBuiltup1/40EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹32.5 Lacs₹3,869 per sq.ft.₹18,627/MonthEstimated EMI840 sqftBuiltup1/14EastFacing1 BHKApartment Type2BathroomsNoneParkingGet Owner Details
#
# Not under loan₹ ₹38 Lacs₹5,938 per sq.ft.₹21,779/MonthEstimated EMI640 sqftBuiltup1/12Green NeighbourhoodNorthFacing1 BHKApartment Type1BathroomsNoneParkingGet Owner Details
#
# Under Loan₹ ₹1.35 Crores₹8,812 per sq.ft.₹77,374/MonthEstimated EMI1,532 sqftBuiltup1/23EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹78 Lacs₹7,685 per sq.ft.₹44,705/MonthEstimated EMI1,015 sqftBuiltup1/36WestFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹64.9 Lacs₹8,331 per sq.ft.₹37,197/MonthEstimated EMI779 sqftBuiltup1/16North-EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹72 Lacs₹5,143 per sq.ft.₹41,266/MonthEstimated EMI1,400 sqftBuiltup1/27WestFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹40 Lacs₹6,126 per sq.ft.₹22,925/MonthEstimated EMI653 sqftBuiltup1/20Commute FriendlyWestFacing1 BHKApartment Type1BathroomsCarParkingGet Owner Details

# %%
# Read html file for text extraction

with open('data.html', 'r') as f:
    contents = f.read()
    soup = BeautifulSoup(contents, 'html.parser')
    results = soup.find('a').get('href')
    results = 'https://www.nobroker.in/' + results + "?nbFr=list-rent"
    print(results)
# Out:
# https://www.nobroker.in//property/2-bhk-apartment-for-rent-in-kharadi-pune-for-rs-34000/8a9fa88276f7fe010176f8939ae7105c/detail?nbFr=list-rent

# %%
scraped_data = {}
links = []
minimumRent = []
minimumDeposit = []
builtup_area = []
furnishing = []
apartment_type = []
for i in data_html:
    minimumRent.append(i.find("div", attrs={"class": "flex", "id": "minimumRent"}).text)
    minimumDeposit.append(
        i.find(
            "div", attrs={"class": "font-semi-bold heading-6", "id": "roomType"}
        ).text
    )
    builtup_area.append(
        i.find(
            "div", attrs={"class": "flex", "id": "unitCode"}
        ).text
    )
    furnishing.append(
        i.find("div", attrs={"class": "font-semibold"}).text
    )
    apartment_type.append(i.find('div',attrs={"class": "flex flex-1 pl-0.5p"}).find("div", attrs={"class": "font-semibold"}).text
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 26
#      23 apartment_type.append(i.find('div',attrs={"class": "flex flex-1 pl-0.5p"}).find("div", attrs={"class": "font-semibold"}).text
#      24 )
#      25 # Getting the link of the property
# ---> 26 links.append(i.find("h2", attrs={"class":"heading-6 flex items-center font-semi-bold m-0"}).find("a").get("href"))
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
links
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
