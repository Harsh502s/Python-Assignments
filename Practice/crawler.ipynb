# %%
# Creating a web crawler to scrape data from the 99acres.com website

# Importing the required libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
url = r'https://www.nobroker.in/property/sale/pune/multiple?searchParam=...&radius=2.0&propertyAge=0&city=pune&locality=Hadapsar,Kharadi,Wagholi#signup-login'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the tags that contain the data you want to extract
results = soup.find_all('div', class_='nb__7nqQI')
for result in results:
    print(result.text, end='\n'*2)
# Out:
# Not under loan₹ ₹92 Lacs₹8,949 per sq.ft.₹52,729/MonthEstimated EMI1,028 sqftBuiltup1/27EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹56 Lacs₹5,895 per sq.ft.₹32,096/MonthEstimated EMI950 sqftBuiltup1/4EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹80 Lacs₹6,400 per sq.ft.₹45,851/MonthEstimated EMI1,250 sqftBuiltup1/16WestFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹1.07 Crores₹7,477 per sq.ft.₹61,326/MonthEstimated EMI1,431 sqftBuiltup1/46EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹1.28 Crores₹13,142 per sq.ft.₹73,362/MonthEstimated EMI974 sqftBuiltup1/39South-EastFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹84 Lacs₹5,970 per sq.ft.₹48,144/MonthEstimated EMI1,407 sqftBuiltup1/26WestFacing3 BHKApartment Type3BathroomsCarParkingGet Owner Details
#
# Not under loan₹ ₹26.5 Lacs₹5,279 per sq.ft.₹15,188/MonthEstimated EMI502 sqftBuiltup1/8EastFacing1 BHKApartment Type1BathroomsBikeParkingGet Owner Details
#
# Under Loan₹ ₹75 Lacs₹5,906 per sq.ft.₹42,985/MonthEstimated EMI1,270 sqftBuiltup1/25EastFacing3 BHKApartment Type3BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹60 Lacs₹6,944 per sq.ft.₹34,388/MonthEstimated EMI864 sqftBuiltup1/33EastFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹64 Lacs₹5,926 per sq.ft.₹36,681/MonthEstimated EMI1,080 sqftBuiltup1/33EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹1.2 Crores₹7,417 per sq.ft.₹68,777/MonthEstimated EMI1,618 sqftBuiltup1/40EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹65 Lacs₹9,091 per sq.ft.₹37,254/MonthEstimated EMI715 sqftBuiltup1/7SouthFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹32.5 Lacs₹3,869 per sq.ft.₹18,627/MonthEstimated EMI840 sqftBuiltup1/14EastFacing1 BHKApartment Type2BathroomsNoneParkingGet Owner Details
#
# Not under loan₹ ₹38 Lacs₹5,938 per sq.ft.₹21,779/MonthEstimated EMI640 sqftBuiltup1/12Green NeighbourhoodNorthFacing1 BHKApartment Type1BathroomsNoneParkingGet Owner Details
#
# Under Loan₹ ₹1.35 Crores₹8,812 per sq.ft.₹77,374/MonthEstimated EMI1,532 sqftBuiltup1/23EastFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹78 Lacs₹7,685 per sq.ft.₹44,705/MonthEstimated EMI1,015 sqftBuiltup1/36WestFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹64.9 Lacs₹8,331 per sq.ft.₹37,197/MonthEstimated EMI779 sqftBuiltup1/16North-EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Not under loan₹ ₹72 Lacs₹5,143 per sq.ft.₹41,266/MonthEstimated EMI1,400 sqftBuiltup1/27WestFacing3 BHKApartment Type3BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹40 Lacs₹6,126 per sq.ft.₹22,925/MonthEstimated EMI653 sqftBuiltup1/20Commute FriendlyWestFacing1 BHKApartment Type1BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹34 Lacs₹5,484 per sq.ft.₹19,486/MonthEstimated EMI620 sqftBuiltup1/11EastFacing1 BHKApartment Type1BathroomsBikeParkingGet Owner Details
#
# Not under loan₹ ₹32 Lacs₹5,517 per sq.ft.₹18,340/MonthEstimated EMI580 sqftBuiltup1/21WestFacing1 BHKApartment Type1BathroomsNoneParkingGet Owner Details
#
# Under Loan₹ ₹45 Lacs₹4,767 per sq.ft.₹25,791/MonthEstimated EMI944 sqftBuiltup1/5Don't KnowFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details
#
# Under Loan₹ ₹87 Lacs₹11,154 per sq.ft.₹49,863/MonthEstimated EMI780 sqftBuiltup1/29SouthFacing2 BHKApartment Type2BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹33 Lacs₹4,889 per sq.ft.₹18,913/MonthEstimated EMI675 sqftBuiltup1/16Don't KnowFacing1 BHKApartment Type1BathroomsCarParkingGet Owner Details
#
# Under Loan₹ ₹54 Lacs₹6,658 per sq.ft.₹30,949/MonthEstimated EMI811 sqftBuiltup1/34EastFacing2 BHKApartment Type2BathroomsBike and CarParkingGet Owner Details

# %%
# Read html file for text extraction

with open(r'C:\Users\ds12\div class=infinite-scroll-component.html', 'r') as f:
    contents = f.read()
    soup = BeautifulSoup(contents, 'html.parser')
    results = soup.find_all('div', class_='nb__7nqQI')
    data = {}
    for result in results:
        print(result.prettify(), end='\n'*2)
# Out:
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 40,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     1,25,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      1,350 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <svg class="no-underline absolute top-1/2 text-white bottom-0 left-0 -mt-2p z-2 cursor-pointer opacity-90 tp:-mt-1p" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <img alt="3 BHK Flat  In Bhujbal Township for Rent  In Kothrud" class="my-0 mx-auto relative flex items-center object-contain" fetchpriority="high" height="100%" src="https://images.nobroker.in/images/8a9f06828757506d018757e3cb862f88/8a9f06828757506d018757e3cb862f88_84715_977589_thumbnail.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#      <span class="rounded-sm absolute bottom-0 left-auto right-0 po:mb-1.5 po:mr-1.5 px-0.5p w-auto h-2p text-12 text-white capitalize tracking-normal text-left font-normal" style="background-color: rgba(0, 0, 0, 0.65);">
#       3/5
#      </span>
#     </div>
#     <meta content="8a9f06828757506d018757e3cb862f88_60334_160060_medium.jpg" itemprop="image"/>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Unfurnished
#         </div>
#         <div class="flex">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#          <div class="flex items-center justify-center ml-1p mt-0.2p">
#           <button class="w-5p text-secondary-color rounded border border-solid border-secondary-color bg-white p-0 m-0 h-2.2p text-12 bg-none btn btn-default btn-sm" id="furnish" type="button">
#            Furnish
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         3 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Family
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         28-Apr-2023
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 15,500
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     30,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      700 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <img alt="1 BHK House  for Rent  In Jagtap Dairy" class="my-0 mx-auto relative flex items-center object-contain" height="100%" src="https://images.nobroker.in/images/ff8081815d851c3f015d87ef28905d58/ff8081815d851c3f015d87ef28905d58_2559_thumbnail.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#     </div>
#     <meta content="ff8081815d851c3f015d87ef28905d58_76518_medium.jpg" itemprop="image"/>
#    </div>
#    <button class="rounded-4 absolute bottom-0 left-auto right-0 po:right-1.5p p-0 po:mb-1.5 po:mr-1.5 w-auto text-12 text-white capitalize tracking-normal text-left font-normal h-2.5p mb-0.5p mr-0.5p btn btn-sm" id="requestPhotos-1682146290000" style="opacity: 1; background: rgb(255, 255, 255);" type="button">
#     <span class="flex items-center mr-0.5p text-my-booking-color font-semibold" style="filter: drop-shadow(rgba(0, 0, 0, 0.275) 0px 3px 6px);">
#      <svg class="mx-1" height="13" viewbox="0 0 16.25 13" width="16.25" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <filter filterunits="userSpaceOnUse" height="13" id="imagesmode_FILL0_wght400_GRAD0_opsz48" width="16.25" x="0" y="0">
#         <feoffset dy="3" input="SourceAlpha">
#         </feoffset>
#         <fegaussianblur result="blur" stddeviation="3">
#         </fegaussianblur>
#         <feflood flood-opacity="0.161">
#         </feflood>
#         <fecomposite in2="blur" operator="in">
#         </fecomposite>
#         <fecomposite in="SourceGraphic">
#         </fecomposite>
#        </filter>
#       </defs>
#       <g filter="url(#imagesmode_FILL0_wght400_GRAD0_opsz48)" transform="matrix(1, 0, 0, 1, 0, 0)">
#        <path d="M82.027,189.512A2.018,2.018,0,0,1,80,187.485v-9.458A2.018,2.018,0,0,1,82.027,176h9.458a2.018,2.018,0,0,1,2.027,2.027v9.458a2.018,2.018,0,0,1-2.027,2.027Zm0-1.013h9.458a1,1,0,0,0,1.013-1.013v-9.458a1,1,0,0,0-1.013-1.013H82.027a1,1,0,0,0-1.013,1.013v9.458a1,1,0,0,0,1.013,1.013Zm1.081-1.858,2.3-2.3,1.233,1.216,1.469-1.858,2.348,2.939Zm.944-5.4a1.185,1.185,0,1,1,.836-.346A1.135,1.135,0,0,1,84.052,181.236Z" data-name="imagesmode_FILL0_wght400_GRAD0_opsz48" fill="#363636" id="imagesmode_FILL0_wght400_GRAD0_opsz48-2" transform="translate(-79 -176)">
#        </path>
#       </g>
#      </svg>
#      Request Photos
#     </span>
#    </button>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Semi furnished
#         </div>
#         <div class="flex">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#          <div class="flex items-center justify-center ml-1p mt-0.2p">
#           <button class="w-5p text-secondary-color rounded border border-solid border-secondary-color bg-white p-0 m-0 h-2.2p text-12 bg-none btn btn-default btn-sm" id="furnish" type="button">
#            Furnish
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         1 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Family
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         01-May-2023
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 25,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     60,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      1,120 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <svg class="no-underline absolute top-1/2 text-white bottom-0 left-0 -mt-2p z-2 cursor-pointer opacity-90 tp:-mt-1p" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <img alt="2 BHK Flat  In Rise Avenue By Rise Realty for Rent  In Balewadi" class="my-0 mx-auto relative flex items-center object-contain" height="100%" src="https://images.nobroker.in/images/8a9fdf8387ad9a220187add42a09260e/8a9fdf8387ad9a220187add42a09260e_5073_44464_medium.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#      <span class="rounded-sm absolute bottom-0 left-auto right-0 po:mb-1.5 po:mr-1.5 px-0.5p w-auto h-2p text-12 text-white capitalize tracking-normal text-left font-normal" style="background-color: rgba(0, 0, 0, 0.65);">
#       5/9
#      </span>
#     </div>
#     <meta content="8a9fdf8387ad9a220187add42a09260e_61005_404050_medium.jpg" itemprop="image"/>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Fully furnished
#         </div>
#         <div class="">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         2 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         All
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         01-May-2023
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 15,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     60,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      520 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <svg class="no-underline absolute top-1/2 text-white bottom-0 left-0 -mt-2p z-2 cursor-pointer opacity-90 tp:-mt-1p" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <img alt="1 BHK Flat  In Shivneri Apartment Happy Colony for Rent  In Happy Colony" class="my-0 mx-auto relative flex items-center object-fill" height="100%" src="https://images.nobroker.in/images/8a9f168286d884d70186d91ca0fc1d53/8a9f168286d884d70186d91ca0fc1d53_27732_328135_medium.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#      <span class="rounded-sm absolute bottom-0 left-auto right-0 po:mb-1.5 po:mr-1.5 px-0.5p w-auto h-2p text-12 text-white capitalize tracking-normal text-left font-normal" style="background-color: rgba(0, 0, 0, 0.65);">
#       3/12
#      </span>
#     </div>
#     <meta content="8a9f168286d884d70186d91ca0fc1d53_62249_765053_medium.jpg" itemprop="image"/>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Semi furnished
#         </div>
#         <div class="flex">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#          <div class="flex items-center justify-center ml-1p mt-0.2p">
#           <button class="w-5p text-secondary-color rounded border border-solid border-secondary-color bg-white p-0 m-0 h-2.2p text-12 bg-none btn btn-default btn-sm" id="furnish" type="button">
#            Furnish
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         1 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         All
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         01-May-2023
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 25,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     60,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      1,050 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <img alt="2 BHK Flat  In Sukhwani Skylines  for Rent  In Pimpri-chinchwad," class="my-0 mx-auto relative flex items-center object-fill" height="100%" src="https://images.nobroker.in/images/8a9ff58287a88d1b0187a89ba17c0732/8a9ff58287a88d1b0187a89ba17c0732_214033_501518_medium.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#      <span class="rounded-sm absolute bottom-0 left-auto right-0 po:mb-1.5 po:mr-1.5 px-0.5p w-auto h-2p text-12 text-white capitalize tracking-normal text-left font-normal" style="background-color: rgba(0, 0, 0, 0.65);">
#       1/8
#      </span>
#     </div>
#     <meta content="8a9ff58287a88d1b0187a89ba17c0732_214033_501518_medium.jpg" itemprop="image"/>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Semi furnished
#         </div>
#         <div class="flex">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#          <div class="flex items-center justify-center ml-1p mt-0.2p">
#           <button class="w-5p text-secondary-color rounded border border-solid border-secondary-color bg-white p-0 m-0 h-2.2p text-12 bg-none btn btn-default btn-sm" id="furnish" type="button">
#            Furnish
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         2 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Family
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Ready to Move
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 16,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     30,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      550 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <img alt="1 BHK House  for Rent  In Pimpri-chinchwad" class="my-0 mx-auto relative flex items-center object-contain" height="100%" src="https://images.nobroker.in/images/8a9fcf828764d46501876535ec8b4982/8a9fcf828764d46501876535ec8b4982_514633_721699_medium.jpg" style="transition: width 0.3s ease-in-out 0s; background-color: rgb(218, 218, 218);" width="100%"/>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
# ...
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 13,500
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     30,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      800 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <div class="lazyload-placeholder" style="height: auto;">
#      </div>
#      <svg class="no-underline absolute top-1/2 bottom-0 right-0 text-white opacity-90 -mt-2p z-2 cursor-pointer tp:-mt-1p transform rotate-180" color="white" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#       <path class="" d="M16.62,2.99 C16.13,2.5 15.34,2.5 14.85,2.99 L6.54,11.3 C6.15,11.69 6.15,12.32 6.54,12.71 L14.85,21.02 C15.34,21.51 16.13,21.51 16.62,21.02 C17.11,20.53 17.11,19.74 16.62,19.25 L9.38,12 L16.63,4.75 C17.11,4.27 17.11,3.47 16.62,2.99 Z" fill="white">
#       </path>
#      </svg>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#      <span class="rounded-sm absolute bottom-0 left-auto right-0 po:mb-1.5 po:mr-1.5 px-0.5p w-auto h-2p text-12 text-white capitalize tracking-normal text-left font-normal" style="background-color: rgba(0, 0, 0, 0.65);">
#       1/5
#      </span>
#     </div>
#     <meta content="8a9f0c8286f4d1950186f5369f383a6e_51253_842902_medium.jpg" itemprop="image"/>
#    </div>
#    <div class="rounded-sm flex items-center justify-center py-0.5p pr-2 h-2p absolute left-1.5p bottom-0 po:left-3.5 z-1 po:mb-1p po:ml-2" style="background: linear-gradient(278deg, rgb(234, 201, 104) 0%, rgb(195, 136, 46) 100%) 0% 0% no-repeat padding-box padding-box transparent;">
#     <div class="h-2p w-2p relative" itemprop="image" style='background-image: url("https://assets.nobroker.in/nb-new/public/Common/nudges/premiumListingIcon.svg"); background-size: 14px; background-position: 3px 3px; cursor: pointer; background-repeat: no-repeat;'>
#     </div>
#     <span class="text-14 text-white capitalize tracking-normal text-left font-semibold">
#      Premium Listing
#     </span>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Semi furnished
#         </div>
#         <div class="flex">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#          <div class="flex items-center justify-center ml-1p mt-0.2p">
#           <button class="w-5p text-secondary-color rounded border border-solid border-secondary-color bg-white p-0 m-0 h-2.2p text-12 bg-none btn btn-default btn-sm" id="furnish" type="button">
#            Furnish
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         1 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Bachelor
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Ready to Move
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="nb__7nqQI">
#  <div class="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0">
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1" id="minDeposit">
#    <div class="font-semi-bold heading-6">
#     <div class="flex" id="minimumRent">
#      â‚¹ 36,000
#      <div class="group relative flex m-0">
#       <div>
#        <div class="bg-grayDark text-white text-center rounded-md py-0.2p px-0.6p absolute left-1/2 -ml-6p opacity-0 transform transition-opacity duration-300 after:absolute after:top-full after:left-1/2 after:-ml-0.5p after:border-0.5p after:border-solid after:border-grayDark group-hover:inline-block group-hover:opacity-100 text-12" style="width: 108px; bottom: 125%; z-index: 5;">
#         <div class="flex">
#          <div class="mt-0 -mr-1.5p ml-1p mb-1.6p w-2p relative left-0.8p bottom-0.2p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 114px 505px; background-size: 190px;'>
#          </div>
#          No Extra Maintenance
#         </div>
#        </div>
#        <div class="block w-1.6p h-1.6p mt-0.3p ml-0.4p" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: 111px 398px; background-size: 150px;'>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="heading-7 flex">
#     Rent (Non-Negotiable)
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r border-r-solid border-card-overview-border-color last:border-r-1">
#    <div class="font-semi-bold heading-6" id="roomType">
#     <span>
#      â‚¹
#     </span>
#     1,50,000
#    </div>
#    <div class="heading-7 flex">
#     Deposit
#    </div>
#   </div>
#   <div class="flex flex-col w-33pe items-center tp:w-half po:w-full" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue">
#    <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue">
#     <meta content="INR" itemprop="unitCode"/>
#     <div class="flex" id="unitCode">
#      1,200 sqft
#     </div>
#    </div>
#    <div class="heading-7">
#     Builtup
#    </div>
#   </div>
#  </div>
#  <div class="p-1.5p pl-0 flex tp:p-0 tp:h-auto nb__MCj8k" style="height: 210px;">
#   <div class="mr-1.5p relative tp:mr-0 nb__2xxq-" style="flex: 2.1 1 0%;">
#    <div class="pl-1.5p po:px-1.5p py-0">
#     <div class="flex bg-white mb-1p rounded-2 bg-clip-padding overflow-hidden relative cursor-pointer tp:mt-0 h-18p tp:h-21p undefined">
#      <div class="lazyload-placeholder" style="height: auto;">
#      </div>
#      <div class="absolute right-0 top-0 m-1p h-1.4p w-1.4p rounded-t-2" style='background-image: url("https://assets.nobroker.in/nb-new/public/List-Page/list_page_sprite_min.png"); background-position: -62px -245px; background-size: 150px;'>
#      </div>
#     </div>
#     <meta content="8a9fb082796489de0179649683580552_67688_323943_medium.jpg" itemprop="image"/>
#    </div>
#   </div>
#   <div style="flex: 3 1 0%;">
#    <div class="border-3 border-double border-property-views-border-color flex flex-col">
#     <div class="flex p-0.5p border-b border-b-solid border-b-cardbordercolor items-center" style="min-height: 60px;">
#      <div class="flex-1 border-r border-r-solid border-r-cardbordercolor flex">
#       <div class="py-0 pr-0.5p pl-3p" style='background-image: url("https://assets.nobroker.in/static/img/listing-page-sprite_2.png"); background-position: -21px -332px;'>
#       </div>
#       <div class="flex">
#        <div>
#         <div class="font-semibold">
#          Fully furnished
#         </div>
#         <div class="">
#          <div class="heading-7 text-default-color mt-0.5p">
#           Furnishing
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="mt-1p w-3p h-3p ml-0.5p bg-no-repeat pr-0.5p pl-3.5p" style='background-image: url("https://assets.nobroker.in/static/img/commercial/commercial_icons.png"); background-position: -5px -7px;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         3 BHK
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Apartment Type
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="flex p-0.5p items-center" style="min-height: 60px;">
#      <div class="flex flex-1 border-r border-r-solid border-r-cardbordercolor">
#       <div class="py-0 pr-0.5p pl-3p mt-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/male_Te.png"); background-position: inherit;'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         All
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Preferred Tenants
#        </div>
#       </div>
#      </div>
#      <div class="flex flex-1 pl-0.5p">
#       <div class="w-3p py-0 pr-0.5p pl-3.5p mt-1p ml-0.5p bg-no-repeat" style='background-image: url("https://assets.nobroker.in/static/img/resale/possesion_icon.png");'>
#       </div>
#       <div>
#        <div class="font-semibold">
#         Ready to Move
#        </div>
#        <div class="heading-7 text-default-color mt-0.5p">
#         Available From
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-1.3p flex justify-between">
#     <button class="w-65pe btn btn-primary btn-md" id="getOwnerDetails" type="button">
#      Get Owner Details
#     </button>
#     <button class="hover:bg-card-overview-border-color py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="shortlistProperty" type="button">
#      <span class="my-0 mx-auto bg-no-repeat bg-shortlisticons bg-shortlistps h-3p w-3p">
#       <div class="py-0.2p">
#        <svg class="m-0" color="transparent" style="width: 24px; height: 24px; margin: 2px;" viewbox="0 0 24 24">
#         <path class="" d="M13.91,6.75c-1.17,2.25-4.3,5.31-6.07,6.94c-0.1903,0.1718-0.4797,0.1718-0.67,0C5.39,12.06,2.26,9,1.09,6.75C-1.48,1.8,5-1.5,7.5,3.45C10-1.5,16.48,1.8,13.91,6.75z" fill="transparent" style="transform: scale(1.5, 1.4); stroke: rgb(120, 118, 118); stroke-width: 1.5px; fill: transparent;">
#         </path>
#        </svg>
#       </div>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#     <button class="py-0.7p px-1.5p bg-transparent border border-solid border-gray-300 ml-1p cursor-pointer property-card-action-icon-btn btn btn-none btn-md" id="abuseReport" type="button">
#      <span>
#       <img alt="report abuse" class="h-full w-full" loading="lazy" src="https://assets.nobroker.in/static/img/resale/report_abuse_2.png"/>
#      </span>
#      <span class="tooltip-trigger-text">
#      </span>
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
