# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ds12\College\ML-Assignments\Data Sets\Other Datasets\insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # DAta Viz

# %%
plt.scatter(df['bmi'],df['charges'])
plt.title('Scatter plot of charges vs bmi')
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
countries = pd.read_csv(r"C:\Users\ds12\College\ML-Assignments\Data Sets\Other Datasets\countries.csv")

# %%
df2 = countries[countries.year == 2007]
df2
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 11           Afghanistan      Asia  2007          43.828    31889923
# 23               Albania    Europe  2007          76.423     3600523
# 35               Algeria    Africa  2007          72.301    33333216
# 47                Angola    Africa  2007          42.731    12420476
# 59             Argentina  Americas  2007          75.320    40301927
# ...                  ...       ...   ...             ...         ...
# 1655             Vietnam      Asia  2007          74.249    85262356
# 1667  West Bank and Gaza      Asia  2007          73.422     4018332
# 1679         Yemen, Rep.      Asia  2007          62.698    22211743
# 1691              Zambia    Africa  2007          42.384    11746035
# 1703            Zimbabwe    Africa  2007          43.487    12311143
#
#       gdpPerCapita
# 11      974.580338
# 23     5937.029526
# 35     6223.367465
# 47     4797.231267
# 59    12779.379640
# ...

# %%
plt.scatter(df2['gdpPerCapita'],df2['lifeExpectancy'])
plt.title('Scatter plot of lifeExp vs gdpPercap')
plt.xlabel('gdpPercap')
plt.ylabel('lifeExp')
plt.show()

# %%
sns.displot(df2['gdpPerCapita'],kde=True)

# %%
sns.displot(np.log10(df2['gdpPerCapita']),kde=True)

# %%
plt.scatter(np.log10(df2['gdpPerCapita']),df2['lifeExpectancy'])
plt.title('Scatter plot of lifeExp vs gdpPercap')
plt.xlabel('gdpPercap')
plt.ylabel('lifeExp')
plt.show()

# %% [markdown]
# # Bubble Plot

# %%
top_countries = countries.head(50)
plt.figure(figsize=(10,10))
sns.scatterplot(data=top_countries,x='gdpPerCapita',y='lifeExpectancy',hue='continent',size='population',sizes=(20,1000),legend=True,alpha = 0.5)
# Out:
# <Axes: xlabel='gdpPerCapita', ylabel='lifeExpectancy'>

# %%
national_parks = pd.read_csv(r"C:\Users\ds12\College\ML-Assignments\Data Sets\Other Datasets\national_parks.csv")

# %%
national_parks.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
sns.histplot(data=national_parks,x='GrandCanyon',kde=True,bins=10)
# Out:
# <Axes: xlabel='GrandCanyon', ylabel='Count'>

# %%
plt.hist(national_parks['GrandCanyon'],bins=10,density=True,alpha=0.5,edgecolor='black',facecolor='purple');

# %%
plt.hist(national_parks['GrandCanyon'],bins=10,density=True,alpha=0.5,edgecolor='black',facecolor='purple');
plt.hist(national_parks['BryceCanyon'],bins=10,density=True,alpha=0.5,edgecolor='black',facecolor='blue');
plt.show()

# %%
plt.hist2d(national_parks['GrandCanyon'],national_parks['Year'],bins=(50,50),cmap='BuPu_r');

# %% [markdown]
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
countries
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
data = countries.groupby('country')['population'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(10,10))
plt.bar(data.index,data.values)
plt.tick_params(axis='x',rotation=90)
plt.title('Top 10 countries with highest population')
plt.xlabel('Countries')
plt.ylabel('Population in Millions')
# Adding the values on top of the bars
for i in range(len(data)):
    plt.text(x=i,y=data.values[i],s=round(data.values[i]/100000,2),ha = 'center',va='bottom',color='black',fontsize=10)
plt.show()

# %%
plt.stem(data.index,data.values)
plt.tick_params(axis='x',rotation=90)

# %%
all_countries = countries.groupby('country')['population'].sum().sort_values(ascending=False)
plt.stem(all_countries.values,all_countries.index)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# # SIMPLE LINE GRAPH

# %%
plt.figure(figsize=(5,10))
plt.plot(national_parks['GrandCanyon'])

plt.plot(national_parks['BryceCanyon'])

# %%
# Plotted the two lines on the same plot with theri axes at opposite sides of the plot
fig, ax1 = plt.subplots();
ax2 = ax1.twinx();

# Plotting the two lines with x axis as year and y axis as the number of visitors

ax1.plot(national_parks['Year'],national_parks['GrandCanyon'],color='green');
ax2.plot(national_parks['Year'],national_parks['BryceCanyon'],color='purple');

# Setting the labels for the two axes
ax1.set_ylabel('Grand Canyon Visitors',color='green');
ax2.set_ylabel('Bryce Canyon Visitors',color='purple');

# Setting the title for the plot
plt.title('Visitors to Grand Canyon and Bryce Canyon');

# Setting the x axis label
plt.xlabel('Year');
