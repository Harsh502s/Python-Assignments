# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Heart Data

# %%
df = pd.read_csv(r'C:\Users\ds12\College\Python-Assignments\Dataset\heartdiseases.csv')
df.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...  V67  V68  V69  V70  V71  V72  \
# 0   1   0  63   1  -9  -9  -9  -9   1  145  ...    1    1    1    1    1    1
# 1   2   0  67   1  -9  -9  -9  -9   4  160  ...    1    1    1    1    1    1
# 2   3   0  67   1  -9  -9  -9  -9   4  120  ...    2    2    1    1    1    7
# 3   4   0  37   1  -9  -9  -9  -9   3  130  ...    1    1    1    1    1    1
# 4   6   0  41   0  -9  -9  -9  -9   2  130  ...    1    1    1    1    1    1
#
#    V73  V74  V75   V76
# 0    1   -9   -9  name
# 1    1   -9   -9  name
# 2    3   -9   -9  name
# 3    1   -9   -9  name
# 4    1   -9   -9  name
#
# [5 rows x 76 columns]

# %%
df.describe()
# Out:
#                V1     V2          V3          V4     V5     V6          V7  \
# count  282.000000  282.0  282.000000  282.000000  282.0  282.0  282.000000
# mean   151.517730    0.0   54.411348    0.677305   -9.0   -9.0   -9.095745
# std     87.131234    0.0    9.053083    0.468338    0.0    0.0    0.924970
# min      1.000000    0.0   29.000000    0.000000   -9.0   -9.0  -18.000000
# 25%     75.250000    0.0   48.000000    0.000000   -9.0   -9.0   -9.000000
# 50%    151.500000    0.0   55.000000    1.000000   -9.0   -9.0   -9.000000
# 75%    227.750000    0.0   61.000000    1.000000   -9.0   -9.0   -9.000000
# max    298.000000    0.0   77.000000    1.000000   -9.0   -9.0   -9.000000
#
#                V8          V9         V10  ...         V65         V66  \
# count  282.000000  282.000000  282.000000  ...  282.000000  282.000000
# mean    -8.868794    4.432624  130.269504  ...    0.946809   -8.783688
# std      1.268487   12.365608   22.218225  ...    1.514112    1.470716
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 76 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      282 non-null    int64
#  1   V2      282 non-null    int64
#  2   V3      282 non-null    int64
#  3   V4      282 non-null    int64
#  4   V5      282 non-null    int64
#  5   V6      282 non-null    int64
#  6   V7      282 non-null    int64
#  7   V8      282 non-null    int64
#  8   V9      282 non-null    int64
#  9   V10     282 non-null    int64
#  10  V11     282 non-null    int64
#  11  V12     282 non-null    int64
#  12  V13     282 non-null    int64
#  13  V14     282 non-null    int64
#  14  V15     282 non-null    int64
#  15  V16     282 non-null    int64
#  16  V17     282 non-null    int64
#  17  V18     282 non-null    int64
#  18  V19     282 non-null    int64
#  19  V20     282 non-null    int64
#  20  V21     282 non-null    int64
#  21  V22     282 non-null    int64
# ...

# %%
# Replacing -9 to NaN

df.replace(-9, np.nan, inplace=True)

# %%
subset = df.iloc[:,:58]
subset.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...  V49  V50  V51  V52  V53  V54  \
# 0   1   0  63   1 NaN NaN NaN NaN   1  145  ...  NaN  NaN  6.0  NaN  NaN  NaN
# 1   2   0  67   1 NaN NaN NaN NaN   4  160  ...  NaN  NaN  3.0  NaN  NaN  NaN
# 2   3   0  67   1 NaN NaN NaN NaN   4  120  ...  NaN  NaN  7.0  NaN  NaN  NaN
# 3   4   0  37   1 NaN NaN NaN NaN   3  130  ...  NaN  NaN  3.0  NaN  NaN  NaN
# 4   6   0  41   0 NaN NaN NaN NaN   2  130  ...  NaN  NaN  3.0  NaN  NaN  NaN
#
#    V55  V56  V57  V58
# 0    2   16   81    0
# 1    2    5   81    2
# 2    2   20   81    1
# 3    2    4   81    0
# 4    2   18   81    0
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 76 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      282 non-null    int64
#  1   V2      282 non-null    int64
#  2   V3      282 non-null    int64
#  3   V4      282 non-null    int64
#  4   V5      0 non-null      float64
#  5   V6      0 non-null      float64
#  6   V7      3 non-null      float64
#  7   V8      3 non-null      float64
#  8   V9      282 non-null    int64
#  9   V10     282 non-null    int64
#  10  V11     282 non-null    int64
#  11  V12     279 non-null    float64
#  12  V13     3 non-null      float64
#  13  V14     277 non-null    float64
#  14  V15     277 non-null    float64
#  15  V16     279 non-null    float64
#  16  V17     26 non-null     float64
#  17  V18     282 non-null    int64
#  18  V19     282 non-null    int64
#  19  V20     282 non-null    int64
#  20  V21     282 non-null    int64
# ...

# %% [markdown]
# # Flight DataSet

# %%
df2 = pd.read_csv(r'C:\Users\ds12\College\Python-Assignments\Dataset\flight_data.csv')
df2.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute      time_hour
# 0      1400     5      15  1/1/2013 5:00
# ...

# %%
df2.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
# ...

# %%
flight_1jan = df2[(df2['month'] == 1) & (df2['day'] == 1)]
flight_1jan
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# ..    ...    ...  ...       ...             ...        ...       ...
# 837  2013      1    1    2356.0            2359       -3.0     425.0
# 838  2013      1    1       NaN            1630        NaN       NaN
# 839  2013      1    1       NaN            1935        NaN       NaN
# 840  2013      1    1       NaN            1500        NaN       NaN
# 841  2013      1    1       NaN             600        NaN       NaN
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
delayed_flights = df2[df2['dep_delay'] > 2]
delayed_flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1       2013      1    1     533.0             529        4.0     850.0
# 25      2013      1    1     608.0             600        8.0     807.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 27      2013      1    1     613.0             610        3.0     925.0
# 31      2013      1    1     623.0             610       13.0     920.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336759  2013      9   30    2207.0            2140       27.0    2257.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
# Find all flights

# a. Had an delay of 2 or more hours

# b. Flew to Houston (IAH or HOU)

# c. Were operated by Unites, American or Delta

# d. Departed in summer(March, April , May)

# e. Arrived more than 2 hours late but didn’t leave late

# f. Departed between midnight and 6.00 am

flight_details = df2[(df2['dep_delay'] > 2) & (df2['dest'] == 'IAH' | df2['dest'] == 'HOU') & (df2['carrier'] == 'UA' | df2['carrier'] == 'AA' | df2['carrier'] == 'DL') & (df2['month'] == 3 | df2['month'] == 4 | df2['month'] == 5) & (df2['arr_delay'] > 2 & df2['dep_delay'] < 2) & (df2['dep_time'] > 0 & df2['dep_time'] < 600)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...
